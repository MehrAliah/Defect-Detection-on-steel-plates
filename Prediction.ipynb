# %%
import tensorflow as tf
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense,Conv2D,MaxPooling2D,Flatten, BatchNormalization,Dropout
import matplotlib.pyplot as plt
from keras import callbacks
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score,ConfusionMatrixDisplay
import seaborn as sns
import cv2
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import EarlyStopping
from keras.preprocessing.image import ImageDataGenerator

# %%
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
import numpy as np
import cv2
import matplotlib.pyplot as plt


# Load the saved model
model = tf.keras.models.load_model(r"D:\Internship\models\Model 11\model-11.h5")



# Set the parameters for image classification
batch_size = 16
img_size = 150
img_path = r"D:\Internship\Gray sacle sail dataset\IMG-20230814-WA0046.jpg"
# Preprocess the image
test_datagen = image.ImageDataGenerator(rescale=1./255)

# Load and preprocess the image
img = image.load_img(img_path, target_size=(img_size, img_size), color_mode='grayscale')
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array = img_array / 255.0  # Normalize the image pixel values

# Display the image
plt.imshow(img)
plt.axis('off')
plt.show()

# Make the prediction
class_mapping = {0: 'crazing', 1: 'inclusion', 2: 'patches', 3: 'pitted_surface', 4: 'rolled-in_scale', 5: 'scratches'}
prediction = model.predict(img_array)
predicted_class = np.argmax(prediction)
predicted_class_name = class_mapping[predicted_class]

# Print the predicted class
print("Predicted class:", predicted_class_name)
print("index          :", predicted_class)
# Out:
# 1/1 [==============================] - 0s 153ms/step
# Predicted class: inclusion
# index          : 1
